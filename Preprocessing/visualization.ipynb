# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_prices_returns(stock, year):
    prices_df = pd.read_csv(f'/Users/raunaksandhu/Desktop/UNI/4th YR/Winter/MATH 518/FTS_Forecasting/ProcessedCSVData/{year}_{stock}_prices.csv')
    plt.plot(prices_df['TimeStamp'], prices_df[stock])
    plt.title(f'{stock} Prices in {year}')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.show()

    returns_df = pd.read_csv(f'/Users/raunaksandhu/Desktop/UNI/4th YR/Winter/MATH 518/FTS_Forecasting/ProcessedCSVData/{year}_{stock}_returns.csv')
    plt.plot(returns_df['TimeStamp'], returns_df['returns'])
    plt.title(f'{stock} Returns in {year}')
    plt.xlabel('Time')
    plt.ylabel('Daily Returns')
    plt.show()

# %%
plot_prices_returns('SPY', 2020)
plot_prices_returns('QQQ', 2020)

# note the stock split in 2020
plot_prices_returns('AAPL', 2020)

plot_prices_returns('MSFT', 2020)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plot_prices_returns('SPY', 2020)
#       2 plot_prices_returns('QQQ', 2020)
#
# Cell In[12], line 18, in plot_prices_returns(stock, year)
#      16 plt.xlabel('Time')
#      17 plt.ylabel('Daily Returns')
# ---> 18 plt.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...
